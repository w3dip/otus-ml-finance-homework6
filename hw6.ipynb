# %% [markdown]
# #### Загрузим данные и посмотрим на них

# %%
# !pip install matplotlib -q
# !pip install pandas -q

# !pip install "numpy<2"

import warnings
import matplotlib.pyplot as plt

from pandas import DataFrame

warnings.filterwarnings("ignore")

# !pip install pandas -q

import pandas as pd
# Хак чтобы работало на Anaconda под MacOs 10.15.7 Catalina
pd.DataFrame.iteritems = pd.DataFrame.items
# Out:
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (1.26.4)

# %%
# !pip install plotly -q

import plotly.graph_objects as go

def linear_plot(df, title):
    fig = go.Figure([go.Scatter(x=df['date'], y=df['close'], mode='lines')])
    fig.update_layout(plot_bgcolor='white',
                      xaxis_title='Date',
                      yaxis_title='Price',
                      title=title)
    fig.show()

def candlestick_plot(df, title):
    fig = go.Figure([go.Candlestick(x=df['date'],
                                open=df['open'],
                                high=df['high'],
                                low=df['low'],
                                close=df['close'])])
    fig.update_layout(xaxis_rangeslider_visible=False,
                      plot_bgcolor='white',
                      xaxis_title='Date',
                      yaxis_title='Price',
                      title=title)
    fig.update_yaxes(fixedrange=False)
    fig.show()

# %% [markdown]
# #### Настроим окружение

# %%
import os
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

# %%
# !pip install git+https://github.com/kernc/backtesting.py.git -q

from backtesting import Backtest, Strategy
from backtesting.lib import crossover
from backtesting.test import SMA
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# !pip install torch -q

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# #### Зафиксируем SEED

# %%
import random
import numpy as np

SEED = 777

def seed_everything(seed: int = 42) -> None:
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True)
    print(f"Using {seed} seed")

seed_everything(SEED)
# Out:
# Using 777 seed

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ### Загрузим данные

# %%
# !pip install ccxt -q

import ccxt
import time

def get_data(symbol, timeframe, since):
    exchange = ccxt.binance()
    since = exchange.parse8601(since)
    all_ohlcvs = []

    while True:
        try:
            ohlcvs = exchange.fetch_ohlcv(symbol, timeframe, since)
            all_ohlcvs += ohlcvs
            if len(ohlcvs):
                print('Fetched', len(ohlcvs), symbol, timeframe, 'candles from', exchange.iso8601(ohlcvs[0][0]))
                since = ohlcvs[-1][0] + 1
                sleep_interval = exchange.rateLimit / 1000
                print('Sleep for', sleep_interval)
                time.sleep(sleep_interval)
            else:
                break
        except Exception as e:
            print(type(e).__name__, str(e))
    print('Fetched', len(all_ohlcvs), symbol, timeframe, 'candles in total')

    df = pd.DataFrame(all_ohlcvs)
    df.columns = ['date','open','high','low','close','volume']
    df = df.sort_values(by='date')
    df = df.drop_duplicates(subset='date').reset_index(drop=True)
    df['date'] = pd.to_datetime(df['date'], unit='ms')
    df.to_csv(symbol.replace('/', '_') + '_' + timeframe + '.csv', index=False)
    return df

# %%
symbol = 'ETH/USDT'
timeframe = '1d'
df = get_data(symbol, timeframe, '2020-01-01T00:00:00Z')
df
# Out:
# Fetched 500 ETH/USDT 1d candles from 2020-01-01T00:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1d candles from 2021-05-15T00:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1d candles from 2022-09-27T00:00:00.000Z
# Sleep for 0.05
# Fetched 337 ETH/USDT 1d candles from 2024-02-09T00:00:00.000Z
# Sleep for 0.05
# Fetched 1837 ETH/USDT 1d candles in total
#            date     open     high      low    close        volume
# 0    2020-01-01   129.16   133.05   128.68   130.77  144770.52197
# 1    2020-01-02   130.72   130.78   126.38   127.19  213757.05806
# 2    2020-01-03   127.19   135.14   125.88   134.35  413055.18895
# 3    2020-01-04   134.37   135.85   132.50   134.20  184276.17102
# 4    2020-01-05   134.20   138.19   134.19   135.37  254120.45343
# ...         ...      ...      ...      ...      ...           ...
# 1832 2025-01-06  3636.00  3744.83  3610.63  3687.45  329642.36480
# 1833 2025-01-07  3687.44  3700.86  3356.31  3381.31  541543.28740
# 1834 2025-01-08  3381.31  3415.10  3208.20  3327.29  584749.96270
# 1835 2025-01-09  3327.29  3357.27  3158.00  3219.20  501818.42470
# 1836 2025-01-10  3219.20  3321.25  3193.97  3280.01  380177.32230
#
# [1837 rows x 6 columns]

# %%
linear_plot(df, 'ETH/USDT')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fa59f285-4bb6-4a51-9f6b-0ec03843a0fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa59f285-4bb6-4a51-9f6b-0ec03843a0fa")) {                    Plotly.newPlot(                        "fa59f285-4bb6-4a51-9f6b-0ec03843a0fa",                        [{"mode":"lines","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020 ...

# %%
df = pd.read_csv(symbol.replace('/', '_') + '_' + timeframe + '.csv')
df = df.sort_values(by='date')
df = df.drop_duplicates(subset='date').reset_index(drop=True)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df
# Out:
#                open     high      low    close        volume
# date
# 2020-01-01   129.16   133.05   128.68   130.77  144770.52197
# 2020-01-02   130.72   130.78   126.38   127.19  213757.05806
# 2020-01-03   127.19   135.14   125.88   134.35  413055.18895
# 2020-01-04   134.37   135.85   132.50   134.20  184276.17102
# 2020-01-05   134.20   138.19   134.19   135.37  254120.45343
# ...             ...      ...      ...      ...           ...
# 2025-01-06  3636.00  3744.83  3610.63  3687.45  329642.36480
# 2025-01-07  3687.44  3700.86  3356.31  3381.31  541543.28740
# 2025-01-08  3381.31  3415.10  3208.20  3327.29  584749.96270
# 2025-01-09  3327.29  3357.27  3158.00  3219.20  501818.42470
# 2025-01-10  3219.20  3321.25  3193.97  3280.01  380177.32230
#
# [1837 rows x 5 columns]

# %%
df.shape
# Out:
# (1837, 5)

# %%
df.isnull().sum()
# Out:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
df.describe()
# Out:
#               open         high          low        close        volume
# count  1837.000000  1837.000000  1837.000000  1837.000000  1.837000e+03
# mean   1988.180996  2044.819864  1925.764692  1989.901747  6.440248e+05
# std    1150.068238  1181.305270  1113.214327  1149.654111  4.901126e+05
# min     107.670000   118.500000    86.000000   107.820000  5.851962e+04
# 25%    1253.220000  1291.000000  1211.670000  1254.250000  3.288816e+05
# 50%    1871.990000  1907.920000  1842.640000  1872.010000  5.081983e+05
# 75%    2920.990000  2984.520000  2817.000000  2921.730000  8.061430e+05
# max    4807.980000  4868.000000  4713.890000  4807.980000  4.663240e+06

# %%
# Удалим значения где нет объемов
df = df.drop(df[df['volume']==0.0].index)

# %% [markdown]
# #### Преобразуем данные в формат, пригодный для бэктестинга

# %%
df = df.reset_index()
df.columns = df.columns.str.capitalize()
df.rename(columns={'Date': 'Datetime'}, inplace=True)
df["Datetime"] = pd.to_datetime(df["Datetime"])
df.set_index('Datetime', inplace=True)
df
# Out:
#                Open     High      Low    Close        Volume
# Datetime
# 2020-01-01   129.16   133.05   128.68   130.77  144770.52197
# 2020-01-02   130.72   130.78   126.38   127.19  213757.05806
# 2020-01-03   127.19   135.14   125.88   134.35  413055.18895
# 2020-01-04   134.37   135.85   132.50   134.20  184276.17102
# 2020-01-05   134.20   138.19   134.19   135.37  254120.45343
# ...             ...      ...      ...      ...           ...
# 2025-01-06  3636.00  3744.83  3610.63  3687.45  329642.36480
# 2025-01-07  3687.44  3700.86  3356.31  3381.31  541543.28740
# 2025-01-08  3381.31  3415.10  3208.20  3327.29  584749.96270
# 2025-01-09  3327.29  3357.27  3158.00  3219.20  501818.42470
# 2025-01-10  3219.20  3321.25  3193.97  3280.01  380177.32230
#
# [1837 rows x 5 columns]

# %% [markdown]
# #### Разобьем данные на обучающую и тестовую выборки

# %%
data = df.copy()
data
# Out:
#                Open     High      Low    Close        Volume
# Datetime
# 2020-01-01   129.16   133.05   128.68   130.77  144770.52197
# 2020-01-02   130.72   130.78   126.38   127.19  213757.05806
# 2020-01-03   127.19   135.14   125.88   134.35  413055.18895
# 2020-01-04   134.37   135.85   132.50   134.20  184276.17102
# 2020-01-05   134.20   138.19   134.19   135.37  254120.45343
# ...             ...      ...      ...      ...           ...
# 2025-01-06  3636.00  3744.83  3610.63  3687.45  329642.36480
# 2025-01-07  3687.44  3700.86  3356.31  3381.31  541543.28740
# 2025-01-08  3381.31  3415.10  3208.20  3327.29  584749.96270
# 2025-01-09  3327.29  3357.27  3158.00  3219.20  501818.42470
# 2025-01-10  3219.20  3321.25  3193.97  3280.01  380177.32230
#
# [1837 rows x 5 columns]

# %%
# Определяем дату начала тестовой выборки
test_start_date = data.index.max() - pd.DateOffset(months=6)

# Разделение данных на тренировочную и тестовую выборки по времени
train_data = data[data.index < test_start_date]
test_data = data[data.index >= test_start_date]

print(f"Train size: {len(train_data)}, Test size: {len(test_data)}")
# Out:
# Train size: 1652, Test size: 185

# %% [markdown]
# #### Рассмотрим baseline стратегию

# %%
class Baseline(Strategy):
    n1 = 10
    n2 = 20

    def init(self):
        self.sma1 = self.I(SMA, self.data.Close, self.n1)
        self.sma2 = self.I(SMA, self.data.Close, self.n2)

    def next(self):
        # If sma1 crosses above sma2, close any existing
        # short trades, and buy the asset
        if crossover(self.sma1, self.sma2):
            self.position.close()
            self.buy()

        # Else, if sma1 crosses below sma2, close any existing
        # long trades, and sell the asset
        elif crossover(self.sma2, self.sma1):
            self.position.close()
            self.sell()

# %%
def run_backtest(test_data, strategy):
  bt = Backtest(test_data, Baseline, cash=1_000_000, commission=.002)
  stats = bt.run()
  bt.plot()
  print(stats)

# %%
run_backtest(test_data, Baseline)
# Out:
#   <div id="e81efb0c-3c21-4e5a-8617-70ad17063966" data-root-id="p1512" style="display: contents;"></div>
# Start                     2024-07-10 00:00:00
# End                       2025-01-10 00:00:00
# Duration                    184 days 00:00:00
# Exposure Time [%]                   88.648649
# Equity Final [$]                 819125.19684
# Equity Peak [$]                   1283601.688
# Return [%]                          -18.08748
# Buy & Hold Return [%]                5.770949
# Return (Ann.) [%]                  -32.540603
# Volatility (Ann.) [%]               43.362955
# Sharpe Ratio                        -0.750424
# Sortino Ratio                       -0.769262
# Calmar Ratio                        -0.899274
# Max. Drawdown [%]                  -36.185407
# Avg. Drawdown [%]                  -18.597817
# Max. Drawdown Duration      156 days 00:00:00
# Avg. Drawdown Duration       79 days 00:00:00
# # Trades                                   10
# Win Rate [%]                             30.0
# Best Trade [%]                       19.61509
# Worst Trade [%]                    -12.872496
# Avg. Trade [%]                      -1.980454
# Max. Trade Duration          41 days 00:00:00
# Avg. Trade Duration          17 days 00:00:00
# Profit Factor                         0.71298
# Expectancy [%]                      -1.473451
# SQN                                 -0.540818
# Kelly Criterion                     -0.155789
# _strategy                            Baseline
# _equity_curve                             ...
# _trades                      Size  EntryBa...
# dtype: object

# %% [markdown]
# На простой стратегии скользящих средних получили убыток

# %%
class CFG:
    INPUT_SIZE=1
    HIDDEN_LAYER_SIZE=50
    OUTPUT_SIZE=1
    LEARNING_RATE=0.01
    BATCH_SIZE=128
    EPOCHS=40
    WINDOW=30

# %%
# !pip install scikit-learn -q

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(train_data[["Close"]])
scaled_test = scaler.transform(test_data[["Close"]])

# %%
scaled_train
# Out:
# array([[0.00488281],
#        [0.00412114],
#        [0.00564449],
#        ...,
#        [0.60065615],
#        [0.61938104],
#        [0.62951687]])

# %%
scaled_test
# Out:
# array([[0.63683577],
#        [0.63652088],
#        [0.64382064],
#        [0.65276714],
#        [0.6674794 ],
#        [0.71818193],
#        [0.70982903],
#        [0.69768476],
#        [0.70607809],
#        [0.72246689],
#        [0.72543913],
#        [0.72935815],
#        [0.70886523],
#        [0.71799471],
#        [0.686783  ],
#        [0.6526714 ],
#        [0.67376217],
#        [0.66831555],
#        [0.67281539],
#        [0.68292143],
#        [0.67474086],
#        [0.66485396],
#        [0.65861162],
#        [0.61312594],
#        [0.59483507],
#        [0.54915152],
#        [0.49184921],
#        [0.50072976],
#        [0.47551147],
#        [0.54778561],
#        [0.52997345],
#        [0.53234358],
#        [0.52073972],
#        [0.5562534 ],
#        [0.55202802],
#        [0.54330704],
#        [0.52382685],
#        [0.52868626],
#        [0.53332014],
#        [0.53281803],
#        [0.53796892],
#        [0.52445023],
#        [0.53676683],
#        [0.53510093],
#        [0.56480205],
#        [0.56597648],
#        [0.56132344],
#        [0.54735796],
#        [0.49987873],
#        [0.5149846 ],
#        [0.51483141],
#        [0.51448887],
#        [0.51172513],
#        [0.49315342],
#        [0.5170441 ],
#        [0.49306194],
#        [0.49847026],
#        [0.48104533],
#        [0.45049743],
#        [0.46078431],
#        [0.46583095],
#        [0.47906454],
#        [0.4852388 ],
#        [0.47503276],
#        [0.47954538],
#        [0.49601928],
#        [0.49146625],
#        [0.46983081],
#        [0.46548628],
#        [0.47529871],
#        [0.48230911],
#        [0.50155527],
#        [0.52202053],
#        [0.53287122],
#        [0.5261906 ],
#        [0.54022629],
#        [0.54155178],
#        [0.5259672 ],
#        [0.53709661],
#        [0.55032382],
#        [0.5462346 ],
#        [0.54249217],
#        [0.53070747],
#        [0.49784901],
#        [0.48004323],
#        [0.47700078],
#        [0.49074712],
#        [0.49080031],
#        [0.496198  ],
#        [0.49251302],
#        [0.49638097],
#        [0.48139851],
#        [0.4848069 ],
#        [0.49608524],
#        [0.50393604],
#        [0.50234247],
#        [0.5365711 ],
#        [0.53180956],
#        [0.53259464],
#        [0.53146701],
#        [0.53920505],
#        [0.54048798],
#        [0.5614894 ],
#        [0.54442402],
#        [0.53508604],
#        [0.51419313],
#        [0.51657816],
#        [0.49632353],
#        [0.50523599],
#        [0.51061666],
#        [0.5233141 ],
#        [0.53848805],
#        [0.5428262 ],
#        [0.51291658],
#        [0.51140174],
#        [0.50772952],
#        [0.49996383],
#        [0.48730043],
#        [0.49247898],
#        [0.55616192],
#        [0.59309683],
#        [0.60719848],
#        [0.64218878],
#        [0.65431602],
#        [0.69439551],
#        [0.66720707],
#        [0.65515642],
#        [0.62785097],
#        [0.63448691],
#        [0.64360575],
#        [0.63150616],
#        [0.65954776],
#        [0.6381953 ],
#        [0.63022323],
#        [0.69103818],
#        [0.68507455],
#        [0.69914428],
#        [0.69218495],
#        [0.70352286],
#        [0.68442564],
#        [0.75432751],
#        [0.73847912],
#        [0.74133434],
#        [0.76503353],
#        [0.76588669],
#        [0.75222971],
#        [0.74607886],
#        [0.79358575],
#        [0.78239464],
#        [0.8278548 ],
#        [0.82729099],
#        [0.82897816],
#        [0.7668207 ],
#        [0.74900216],
#        [0.79231133],
#        [0.80290671],
#        [0.8082661 ],
#        [0.80049828],
#        [0.81939125],
#        [0.82516765],
#        [0.80533216],
#        [0.74869366],
#        [0.70405901],
#        [0.71580329],
#        [0.68744468],
#        [0.67529829],
#        [0.70523344],
#        [0.72026484],
#        [0.72107758],
#        [0.68662131],
#        [0.68629366],
#        [0.70129102],
#        [0.69118073],
#        [0.69232111],
#        [0.68720214],
#        [0.69201048],
#        [0.71228426],
#        [0.74490868],
#        [0.75509344],
#        [0.75064891],
#        [0.76159748],
#        [0.69646352],
#        [0.6849703 ],
#        [0.66197321],
#        [0.67491107]])

# %%
def create_sequences(data: np.ndarray, seq_length: int=50) -> tuple[np.ndarray]:
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length, 0])
    return np.array(X), np.array(y)

# %%
X_train, y_train = create_sequences(scaled_train, CFG.WINDOW)
X_test, y_test = create_sequences(scaled_test, CFG.WINDOW)

# %%
X_train
# Out:
# array([[[0.00488281],
#         [0.00412114],
#         [0.00564449],
#         ...,
#         [0.0144293 ],
#         [0.0140208 ],
#         [0.01635476]],
#
#        [[0.00412114],
#         [0.00564449],
#         [0.00561257],
#         ...,
#         [0.0140208 ],
#         [0.01635476],
#         [0.0153548 ]],
#
#        [[0.00564449],
#         [0.00561257],
#         [0.0058615 ],
#         ...,
#         [0.01635476],
#         [0.0153548 ],
#         [0.01612286]],
#
#        ...,
#
#        [[0.75965499],
#         [0.76034646],
#         [0.76562926],
#         ...,
#         [0.62803819],
#         [0.61146004],
#         [0.62955516]],
#
#        [[0.76034646],
#         [0.76562926],
#         [0.75742741],
#         ...,
#         [0.61146004],
#         [0.62955516],
#         [0.60065615]],
#
#        [[0.76562926],
#         [0.75742741],
#         [0.72114779],
#         ...,
#         [0.62955516],
#         [0.60065615],
#         [0.61938104]]])

# %%
class LSTM(nn.Module):
    def __init__(self, input_dim: int, hidden_dim: int, output_dim: int, layer_num: int=3) -> None:
        super().__init__()
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.lstm = torch.nn.LSTM(
            input_dim,
            hidden_dim,
            layer_num,
            batch_first=True
        )
        self.dr = torch.nn.Dropout2d(0.1)
        self.fc = torch.nn.Linear(
            hidden_dim,
            output_dim
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        lstm_out, (hn, cn) = self.lstm(x)
        out = self.fc(lstm_out[:, -1])
        return out

# %%
lstm_model = LSTM(CFG.INPUT_SIZE, CFG.HIDDEN_LAYER_SIZE, CFG.OUTPUT_SIZE).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(lstm_model.parameters(), lr=CFG.LEARNING_RATE)

# %%
def worker_init_fn(worker_id: int) -> None:
    np.random.seed(CFG.SEED + worker_id)

train_data_pt = TensorDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train).float())
full_train_loader = DataLoader(
    train_data_pt,
    batch_size=CFG.BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    worker_init_fn=worker_init_fn
    )

# %%
lstm_model.train()

for epoch in range(CFG.EPOCHS):
    for X_batch, y_batch in full_train_loader:
        optimizer.zero_grad()
        y_pred = lstm_model(X_batch.to(device))
        loss = criterion(y_pred, y_batch.to(device).view(-1, 1))
        loss.backward()
        optimizer.step()
    if (epoch + 1) % 2 == 0:
        print(f"Epoch {epoch + 1}/{CFG.EPOCHS}, Loss: {loss.item()}")
# Out:
# Epoch 2/40, Loss: 0.010650087147951126
# Epoch 4/40, Loss: 0.0014610744547098875
# Epoch 6/40, Loss: 0.0008614597609266639
# Epoch 8/40, Loss: 0.0012823233846575022
# Epoch 10/40, Loss: 0.0006744057754985988
# Epoch 12/40, Loss: 0.000524599920026958
# Epoch 14/40, Loss: 0.0011336266761645675
# Epoch 16/40, Loss: 0.0007500085630454123
# Epoch 18/40, Loss: 0.000405962549848482
# Epoch 20/40, Loss: 0.0005059555405750871
# Epoch 22/40, Loss: 0.0006794806686230004
# Epoch 24/40, Loss: 0.00030215721926651895
# Epoch 26/40, Loss: 0.00026959998649545014
# Epoch 28/40, Loss: 0.0002538647677283734
# Epoch 30/40, Loss: 0.0005795691395178437
# Epoch 32/40, Loss: 0.0005614387919194996
# Epoch 34/40, Loss: 0.0005098194815218449
# Epoch 36/40, Loss: 0.0003549249086063355
# Epoch 38/40, Loss: 0.0010909445118159056
# Epoch 40/40, Loss: 0.0003575959417503327

# %%
lstm_model.eval()

with torch.inference_mode():
    X_test_tensor = torch.from_numpy(X_test).to(device).float()
    predicted_close_prices = lstm_model(X_test_tensor).cpu().numpy()
predicted_close_prices = scaler.inverse_transform(predicted_close_prices)

predicted_close_prices[:5]
# Out:
# array([[2614.117 ],
#        [2627.193 ],
#        [2626.7502],
#        [2580.489 ],
#        [2706.7961]], dtype=float32)

# %%
y_test
# Out:
# array([0.52997345, 0.53234358, 0.52073972, 0.5562534 , 0.55202802,
#        0.54330704, 0.52382685, 0.52868626, 0.53332014, 0.53281803,
#        0.53796892, 0.52445023, 0.53676683, 0.53510093, 0.56480205,
#        0.56597648, 0.56132344, 0.54735796, 0.49987873, 0.5149846 ,
#        0.51483141, 0.51448887, 0.51172513, 0.49315342, 0.5170441 ,
#        0.49306194, 0.49847026, 0.48104533, 0.45049743, 0.46078431,
#        0.46583095, 0.47906454, 0.4852388 , 0.47503276, 0.47954538,
#        0.49601928, 0.49146625, 0.46983081, 0.46548628, 0.47529871,
#        0.48230911, 0.50155527, 0.52202053, 0.53287122, 0.5261906 ,
#        0.54022629, 0.54155178, 0.5259672 , 0.53709661, 0.55032382,
#        0.5462346 , 0.54249217, 0.53070747, 0.49784901, 0.48004323,
#        0.47700078, 0.49074712, 0.49080031, 0.496198  , 0.49251302,
#        0.49638097, 0.48139851, 0.4848069 , 0.49608524, 0.50393604,
#        0.50234247, 0.5365711 , 0.53180956, 0.53259464, 0.53146701,
#        0.53920505, 0.54048798, 0.5614894 , 0.54442402, 0.53508604,
#        0.51419313, 0.51657816, 0.49632353, 0.50523599, 0.51061666,
#        0.5233141 , 0.53848805, 0.5428262 , 0.51291658, 0.51140174,
#        0.50772952, 0.49996383, 0.48730043, 0.49247898, 0.55616192,
#        0.59309683, 0.60719848, 0.64218878, 0.65431602, 0.69439551,
#        0.66720707, 0.65515642, 0.62785097, 0.63448691, 0.64360575,
#        0.63150616, 0.65954776, 0.6381953 , 0.63022323, 0.69103818,
#        0.68507455, 0.69914428, 0.69218495, 0.70352286, 0.68442564,
#        0.75432751, 0.73847912, 0.74133434, 0.76503353, 0.76588669,
#        0.75222971, 0.74607886, 0.79358575, 0.78239464, 0.8278548 ,
#        0.82729099, 0.82897816, 0.7668207 , 0.74900216, 0.79231133,
#        0.80290671, 0.8082661 , 0.80049828, 0.81939125, 0.82516765,
#        0.80533216, 0.74869366, 0.70405901, 0.71580329, 0.68744468,
#        0.67529829, 0.70523344, 0.72026484, 0.72107758, 0.68662131,
#        0.68629366, 0.70129102, 0.69118073, 0.69232111, 0.68720214,
#        0.69201048, 0.71228426, 0.74490868, 0.75509344, 0.75064891,
#        0.76159748, 0.69646352, 0.6849703 , 0.66197321, 0.67491107])

# %%
scaler.inverse_transform(y_test.reshape(-1, 1))[:5]
# Out:
# array([[2598.78],
#        [2609.92],
#        [2555.38],
#        [2722.3 ],
#        [2702.44]])

# %%
def create_sequences_for_strategy(data: np.ndarray, seq_length: int=50) -> tuple[np.ndarray]:
    X = []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
    return np.array(X)

# %%
class LstmStrategy(Strategy):
    def init(self) -> None:
        self.scaler = scaler
        self.model = lstm_model
        self.model.eval()

        self.forecasts = self.I(lambda: np.repeat(np.nan, len(self.data)), name='forecast')

    def next(self) -> None:
        if len(self.data) <= CFG.WINDOW:
            return

        scaled_prices = self.scaler.transform(self.data.df[["Close"]])[-CFG.WINDOW:].reshape(-1, 1)
        with torch.inference_mode():
            tensor = torch.from_numpy(scaled_prices).to(device).float().view(1, CFG.WINDOW, 1)
            predicted_close_price_scaled = self.model(tensor).cpu().numpy()
        predicted_close_price = self.scaler.inverse_transform(predicted_close_price_scaled)[0][0]

        self.forecasts[-1] = predicted_close_price

        if self.data.Close / predicted_close_price < 0.99:
            self.position.close()
            self.buy()

        elif self.data.Close / predicted_close_price > 1.01:
            self.position.close()
            self.sell()

# %%
run_backtest(test_data, LstmStrategy)
# Out:
#   <div id="83b2cecb-c128-4ffb-93af-b290c1533831" data-root-id="p2638" style="display: contents;"></div>
# Start                     2024-07-10 00:00:00
# End                       2025-01-10 00:00:00
# Duration                    184 days 00:00:00
# Exposure Time [%]                   88.648649
# Equity Final [$]                 819125.19684
# Equity Peak [$]                   1283601.688
# Return [%]                          -18.08748
# Buy & Hold Return [%]                5.770949
# Return (Ann.) [%]                  -32.540603
# Volatility (Ann.) [%]               43.362955
# Sharpe Ratio                        -0.750424
# Sortino Ratio                       -0.769262
# Calmar Ratio                        -0.899274
# Max. Drawdown [%]                  -36.185407
# Avg. Drawdown [%]                  -18.597817
# Max. Drawdown Duration      156 days 00:00:00
# Avg. Drawdown Duration       79 days 00:00:00
# # Trades                                   10
# Win Rate [%]                             30.0
# Best Trade [%]                       19.61509
# Worst Trade [%]                    -12.872496
# Avg. Trade [%]                      -1.980454
# Max. Trade Duration          41 days 00:00:00
# Avg. Trade Duration          17 days 00:00:00
# Profit Factor                         0.71298
# Expectancy [%]                      -1.473451
# SQN                                 -0.540818
# Kelly Criterion                     -0.155789
# _strategy                            Baseline
# _equity_curve                             ...
# _trades                      Size  EntryBa...
# dtype: object

# %% [markdown]
# Получили также убыток

# %% [markdown]
# ### Попробуем добавить Bagging

# %%
def create_train_loader(data: pd.DataFrame, start: str, end: str, scaler: MinMaxScaler, batch_size: int) -> DataLoader:
    train_data = data[(data.index >= start) & (data.index < end)]
    scaled_train_data = scaler.transform(train_data[["Close"]])
    X_train, y_train = create_sequences(scaled_train_data, CFG.WINDOW)
    train_data_pt = TensorDataset(
        torch.from_numpy(X_train).to(device).float(),
        torch.from_numpy(y_train).to(device).float()
        )
    train_loader = DataLoader(
        train_data_pt,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        worker_init_fn=worker_init_fn
        )
    return train_loader

# %%
def train_model(
        model: nn.Module,
        criterion: nn.MSELoss,
        optimizer: torch.optim.Adam,
        train_loader: DataLoader,
        epochs: int
        ) -> None:
    model.train()
    for epoch in range(epochs):
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            y_pred = model(X_batch)
            loss = criterion(y_pred, y_batch.view(-1, 1))
            loss.backward()
            optimizer.step()
    model.eval()

# %%
scaler = MinMaxScaler()
_ = scaler.fit(data[data.index < test_start_date][["Close"]])

# %%
bagging_models = [LSTM(CFG.INPUT_SIZE, CFG.HIDDEN_LAYER_SIZE, CFG.OUTPUT_SIZE).to(device) for _ in range(4)]
time_range = [
    ("2020-01-01", "2021-01-01"),
    ("2021-01-01", "2022-01-01"),
    ("2022-01-01", "2023-01-01"),
    ("2023-01-01", str(test_start_date)),
    ]
assert len(bagging_models) == len(time_range)

# %%
# !pip install tqdm -q

from tqdm.auto import tqdm

for idx, one_model in tqdm(enumerate(bagging_models), total=len(bagging_models)):
    train_loader = create_train_loader(data, time_range[idx][0], time_range[idx][1], scaler, CFG.BATCH_SIZE)
    train_model(
        one_model,
        nn.MSELoss(),
        torch.optim.Adam(one_model.parameters(), lr=CFG.LEARNING_RATE),
        train_loader,
        CFG.EPOCHS
        )
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
class Bagging_LstmStrategy(Strategy):
    def init(self) -> None:
        self.scaler = scaler
        self.models = bagging_models
        self.models = [model.eval() for model in self.models]

        # Индикатор для отображения предсказаний модели на графике
        self.forecasts = self.I(lambda: np.repeat(np.nan, len(self.data)), name='forecast')

    def next(self) -> None:
        if len(self.data) <= CFG.WINDOW:
            return

        scaled_prices = self.scaler.transform(self.data.df[["Close"]])[-CFG.WINDOW:].reshape(-1, 1)

        predicted_close_prices = []

        for one_model in self.models:
            with torch.inference_mode():
                tensor = torch.from_numpy(scaled_prices).to(device).float().view(1, CFG.WINDOW, 1)
                predicted_close_price_scaled = one_model(tensor).cpu().numpy()
            predicted_close_price = self.scaler.inverse_transform(predicted_close_price_scaled)[0][0]
            predicted_close_prices.append(predicted_close_price)

        final_predicted_close_price = np.mean(predicted_close_prices)

        self.forecasts[-1] = final_predicted_close_price

        if self.data.Close / predicted_close_price < 0.99:
            self.position.close()
            self.buy()

        elif self.data.Close / predicted_close_price > 1.01:
            self.position.close()
            self.sell()

# %%
run_backtest(test_data, Bagging_LstmStrategy)
# Out:
#   <div id="05bb2b6a-c002-49df-bee8-d81dd8059d3f" data-root-id="p3764" style="display: contents;"></div>
# Start                     2024-07-10 00:00:00
# End                       2025-01-10 00:00:00
# Duration                    184 days 00:00:00
# Exposure Time [%]                   88.648649
# Equity Final [$]                 819125.19684
# Equity Peak [$]                   1283601.688
# Return [%]                          -18.08748
# Buy & Hold Return [%]                5.770949
# Return (Ann.) [%]                  -32.540603
# Volatility (Ann.) [%]               43.362955
# Sharpe Ratio                        -0.750424
# Sortino Ratio                       -0.769262
# Calmar Ratio                        -0.899274
# Max. Drawdown [%]                  -36.185407
# Avg. Drawdown [%]                  -18.597817
# Max. Drawdown Duration      156 days 00:00:00
# Avg. Drawdown Duration       79 days 00:00:00
# # Trades                                   10
# Win Rate [%]                             30.0
# Best Trade [%]                       19.61509
# Worst Trade [%]                    -12.872496
# Avg. Trade [%]                      -1.980454
# Max. Trade Duration          41 days 00:00:00
# Avg. Trade Duration          17 days 00:00:00
# Profit Factor                         0.71298
# Expectancy [%]                      -1.473451
# SQN                                 -0.540818
# Kelly Criterion                     -0.155789
# _strategy                            Baseline
# _equity_curve                             ...
# _trades                      Size  EntryBa...
# dtype: object

# %% [markdown]
# Наконец-то получили прибыль

# %% [markdown]
# ### TSMixer

# %%
class TSMIXER_CFG:
    WINDOW = 80
    BATCH_SIZE = 128
    LR = 1e-5
    SEED = 777

# %%
from sklearn.preprocessing import StandardScaler

# !pip install tensorflow -q

import tensorflow as tf
from tensorflow.keras import layers

class DataLoader:
    def __init__(self, batch_size, seq_len, pred_len, data):
        self.batch_size = batch_size
        self.seq_len = seq_len
        self.pred_len = pred_len
        self.target_slice = slice(0, None)

        self._read_data(data)

    def _read_data(self, df):
        train_df = df[df.index < "2024-01-01"]
        val_df = df[(df.index >= "2024-01-01") & (df.index < test_start_date)]
        test_df = df[df.index >= test_start_date]

        # standardize by training set
        self.scaler = StandardScaler()
        self.scaler.fit(train_df.values)

        def scale_df(df, scaler):
            data = scaler.transform(df.values)
            return pd.DataFrame(data, index=df.index, columns=df.columns)

        self.train_df = scale_df(train_df, self.scaler)
        self.val_df = scale_df(val_df, self.scaler)
        self.test_df = scale_df(test_df, self.scaler)
        self.n_feature = self.train_df.shape[-1]

    def _split_window(self, data):
        inputs = data[:, : self.seq_len, :]
        labels = data[:, self.seq_len :, self.target_slice]

        inputs.set_shape([None, self.seq_len, None])
        labels.set_shape([None, self.pred_len, None])
        return inputs, labels

    def _make_dataset(self, data, shuffle=True):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.utils.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=(self.seq_len + self.pred_len),
            sequence_stride=1,
            shuffle=shuffle,
            batch_size=self.batch_size,
        )
        ds = ds.map(self._split_window)
        return ds

    def inverse_transform(self, data):
        return self.scaler.inverse_transform(data)

    def get_train(self, shuffle: bool=True):
        return self._make_dataset(self.train_df, shuffle=shuffle)

    def get_val(self):
        return self._make_dataset(self.val_df, shuffle=False)

    def get_test(self):
        return self._make_dataset(self.test_df, shuffle=False)

# %%
data_loader = DataLoader(
    batch_size=TSMIXER_CFG.BATCH_SIZE,
    seq_len=TSMIXER_CFG.WINDOW,
    pred_len=1,
    data=data[["Close"]]
    )

tf_train_data = data_loader.get_train()
tf_val_data = data_loader.get_val()
tf_test_data = data_loader.get_test()

# %%
class TransposeLayer(layers.Layer):
    def __init__(self, perm: list[int], **kwargs) -> None:
        super().__init__(**kwargs)
        self.perm = perm

    def call(self, inputs):
        return tf.transpose(inputs, perm=self.perm)

# %%
def res_block(inputs, ff_dim: int):
    norm = layers.LayerNormalization

    # Time mixing
    x = norm(axis=[-2, -1])(inputs)
    x = TransposeLayer(perm=[0, 2, 1])(x)  # [Batch, Channel, Input Length]
    x = layers.Dense(x.shape[-1], activation='relu')(x)
    x = TransposeLayer(perm=[0, 2, 1])(x)  # [Batch, Input Length, Channel]
    x = layers.Dropout(0.7)(x)
    res = x + inputs

    # Feature mixing
    x = norm(axis=[-2, -1])(res)
    x = layers.Dense(ff_dim, activation='relu')(x)  # [Batch, Input Length, FF_Dim]
    x = layers.Dropout(0.7)(x)
    x = layers.Dense(inputs.shape[-1])(x)  # [Batch, Input Length, Channel]
    x = layers.Dropout(0.7)(x)
    return x + res

# %%
def build_model(
    input_shape: tuple[int],
    pred_len: int,
    n_block: int,
    ff_dim: int,
    target_slice,
):
    inputs = tf.keras.Input(shape=input_shape)
    x = inputs  # [Batch, Input Length, Channel]
    for _ in range(n_block):
        x = res_block(x, ff_dim)

    if target_slice:
        x = x[:, :, target_slice]

    # Temporal projection
    x = TransposeLayer(perm=[0, 2, 1])(x)  # [Batch, Channel, Input Length]
    x = layers.Dense(pred_len)(x)  # [Batch, Channel, Output Length]
    outputs = TransposeLayer(perm=[0, 2, 1])(x)  # [Batch, Output Length, Channel])
    return tf.keras.Model(inputs, outputs)

# %%
model = build_model(
    input_shape=(TSMIXER_CFG.WINDOW, data_loader.n_feature),
    pred_len=1,
    n_block=8,
    ff_dim=TSMIXER_CFG.WINDOW,
    target_slice=data_loader.target_slice
)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 80, 1)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization       │ (None, 80, 1)          │            160 │ input_layer[0][0]      │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer           │ (None, 1, 80)          │              0 │ layer_normalization[0… │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1, 80)          │          6,480 │ transpose_layer[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_1         │ (None, 80, 1)          │              0 │ dense[0][0]            │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 80, 1)          │              0 │ transpose_layer_1[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 80, 1)          │              0 │ dropout[0][0],         │
# │                           │                        │                │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_1     │ (None, 80, 1)          │            160 │ add[0][0]              │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 80, 80)         │            160 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 80, 80)         │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 80, 1)          │             81 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 80, 1)          │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 80, 1)          │              0 │ dropout_2[0][0],       │
# │                           │                        │                │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_2     │ (None, 80, 1)          │            160 │ add_1[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_2         │ (None, 1, 80)          │              0 │ layer_normalization_2… │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1, 80)          │          6,480 │ transpose_layer_2[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_3         │ (None, 80, 1)          │              0 │ dense_3[0][0]          │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 80, 1)          │              0 │ transpose_layer_3[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 80, 1)          │              0 │ dropout_3[0][0],       │
# │                           │                        │                │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_3     │ (None, 80, 1)          │            160 │ add_2[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 80, 80)         │            160 │ layer_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 80, 80)         │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 80, 1)          │             81 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 80, 1)          │              0 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 80, 1)          │              0 │ dropout_5[0][0],       │
# │                           │                        │                │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_4     │ (None, 80, 1)          │            160 │ add_3[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_4         │ (None, 1, 80)          │              0 │ layer_normalization_4… │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 1, 80)          │          6,480 │ transpose_layer_4[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_5         │ (None, 80, 1)          │              0 │ dense_6[0][0]          │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 80, 1)          │              0 │ transpose_layer_5[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 80, 1)          │              0 │ dropout_6[0][0],       │
# │                           │                        │                │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_5     │ (None, 80, 1)          │            160 │ add_4[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 80, 80)         │            160 │ layer_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 80, 80)         │              0 │ dense_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 80, 1)          │             81 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 80, 1)          │              0 │ dense_8[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 80, 1)          │              0 │ dropout_8[0][0],       │
# │                           │                        │                │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_6     │ (None, 80, 1)          │            160 │ add_5[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_6         │ (None, 1, 80)          │              0 │ layer_normalization_6… │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 1, 80)          │          6,480 │ transpose_layer_6[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_7         │ (None, 80, 1)          │              0 │ dense_9[0][0]          │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_9 (Dropout)       │ (None, 80, 1)          │              0 │ transpose_layer_7[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 80, 1)          │              0 │ dropout_9[0][0],       │
# │                           │                        │                │ add_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_7     │ (None, 80, 1)          │            160 │ add_6[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 80, 80)         │            160 │ layer_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_10 (Dropout)      │ (None, 80, 80)         │              0 │ dense_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_11 (Dense)          │ (None, 80, 1)          │             81 │ dropout_10[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_11 (Dropout)      │ (None, 80, 1)          │              0 │ dense_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 80, 1)          │              0 │ dropout_11[0][0],      │
# │                           │                        │                │ add_6[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_8     │ (None, 80, 1)          │            160 │ add_7[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_8         │ (None, 1, 80)          │              0 │ layer_normalization_8… │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_12 (Dense)          │ (None, 1, 80)          │          6,480 │ transpose_layer_8[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_9         │ (None, 80, 1)          │              0 │ dense_12[0][0]         │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_12 (Dropout)      │ (None, 80, 1)          │              0 │ transpose_layer_9[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 80, 1)          │              0 │ dropout_12[0][0],      │
# │                           │                        │                │ add_7[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_9     │ (None, 80, 1)          │            160 │ add_8[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_13 (Dense)          │ (None, 80, 80)         │            160 │ layer_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_13 (Dropout)      │ (None, 80, 80)         │              0 │ dense_13[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 80, 1)          │             81 │ dropout_13[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_14 (Dropout)      │ (None, 80, 1)          │              0 │ dense_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 80, 1)          │              0 │ dropout_14[0][0],      │
# │                           │                        │                │ add_8[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_10    │ (None, 80, 1)          │            160 │ add_9[0][0]            │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_10        │ (None, 1, 80)          │              0 │ layer_normalization_1… │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 1, 80)          │          6,480 │ transpose_layer_10[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_11        │ (None, 80, 1)          │              0 │ dense_15[0][0]         │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_15 (Dropout)      │ (None, 80, 1)          │              0 │ transpose_layer_11[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 80, 1)          │              0 │ dropout_15[0][0],      │
# │                           │                        │                │ add_9[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_11    │ (None, 80, 1)          │            160 │ add_10[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 80, 80)         │            160 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_16 (Dropout)      │ (None, 80, 80)         │              0 │ dense_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 80, 1)          │             81 │ dropout_16[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 80, 1)          │              0 │ dense_17[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 80, 1)          │              0 │ dropout_17[0][0],      │
# │                           │                        │                │ add_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_12    │ (None, 80, 1)          │            160 │ add_11[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_12        │ (None, 1, 80)          │              0 │ layer_normalization_1… │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_18 (Dense)          │ (None, 1, 80)          │          6,480 │ transpose_layer_12[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_13        │ (None, 80, 1)          │              0 │ dense_18[0][0]         │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_18 (Dropout)      │ (None, 80, 1)          │              0 │ transpose_layer_13[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 80, 1)          │              0 │ dropout_18[0][0],      │
# │                           │                        │                │ add_11[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_13    │ (None, 80, 1)          │            160 │ add_12[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_19 (Dense)          │ (None, 80, 80)         │            160 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_19 (Dropout)      │ (None, 80, 80)         │              0 │ dense_19[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_20 (Dense)          │ (None, 80, 1)          │             81 │ dropout_19[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_20 (Dropout)      │ (None, 80, 1)          │              0 │ dense_20[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 80, 1)          │              0 │ dropout_20[0][0],      │
# │                           │                        │                │ add_12[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_14    │ (None, 80, 1)          │            160 │ add_13[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_14        │ (None, 1, 80)          │              0 │ layer_normalization_1… │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_21 (Dense)          │ (None, 1, 80)          │          6,480 │ transpose_layer_14[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_15        │ (None, 80, 1)          │              0 │ dense_21[0][0]         │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_21 (Dropout)      │ (None, 80, 1)          │              0 │ transpose_layer_15[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 80, 1)          │              0 │ dropout_21[0][0],      │
# │                           │                        │                │ add_13[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_15    │ (None, 80, 1)          │            160 │ add_14[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_22 (Dense)          │ (None, 80, 80)         │            160 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_22 (Dropout)      │ (None, 80, 80)         │              0 │ dense_22[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_23 (Dense)          │ (None, 80, 1)          │             81 │ dropout_22[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_23 (Dropout)      │ (None, 80, 1)          │              0 │ dense_23[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 80, 1)          │              0 │ dropout_23[0][0],      │
# │                           │                        │                │ add_14[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item (GetItem)        │ (None, 80, 1)          │              0 │ add_15[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_16        │ (None, 1, 80)          │              0 │ get_item[0][0]         │
# │ (TransposeLayer)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_24 (Dense)          │ (None, 1, 1)           │             81 │ transpose_layer_16[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transpose_layer_17        │ (None, 1, 1)           │              0 │ dense_24[0][0]         │
# │ (TransposeLayer)          │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 56,409 (220.35 KB)
#  Trainable params: 56,409 (220.35 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.set_random_seed(TSMIXER_CFG.SEED)

optimizer = tf.keras.optimizers.Adam(TSMIXER_CFG.LR)

model.compile(optimizer, loss='mse', metrics=['mae', 'mse'])

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='tsmixer_checkpoints/model.weights.h5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True
)

early_stop_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5
)

# %%
history = model.fit(
    tf_train_data,
    epochs=500,
    validation_data=tf_val_data,
    callbacks=[checkpoint_callback, early_stop_callback]
)
# Out:
# Epoch 1/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 40.6595 - mae: 5.1480 - mse: 40.6595
# Epoch 1: val_loss improved from inf to 28.06126, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 106s 4s/step - loss: 40.6678 - mae: 5.1515 - mse: 40.6678 - val_loss: 28.0613 - val_mae: 4.9964 - val_mse: 28.0613
# Epoch 2/500
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 39.2757 - mae: 5.0121 - mse: 39.2757
# Epoch 2: val_loss improved from 28.06126 to 27.05908, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 39.5754 - mae: 5.0395 - mse: 39.5754 - val_loss: 27.0591 - val_mae: 4.8982 - val_mse: 27.0591
# Epoch 3/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 42.2149 - mae: 5.1132 - mse: 42.2149
# Epoch 3: val_loss improved from 27.05908 to 26.07945, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 41.1258 - mae: 5.0865 - mse: 41.1258 - val_loss: 26.0795 - val_mae: 4.8001 - val_mse: 26.0795
# Epoch 4/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 39.6901 - mae: 5.1528 - mse: 39.6901
# Epoch 4: val_loss improved from 26.07945 to 25.13638, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 39.5014 - mae: 5.1199 - mse: 39.5014 - val_loss: 25.1364 - val_mae: 4.7042 - val_mse: 25.1364
# Epoch 5/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 38.5944 - mae: 4.9990 - mse: 38.5944
# Epoch 5: val_loss improved from 25.13638 to 24.19982, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 39.5334 - mae: 5.0633 - mse: 39.5334 - val_loss: 24.1998 - val_mae: 4.6061 - val_mse: 24.1998
# Epoch 6/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 38.5925 - mae: 5.0404 - mse: 38.5925
# Epoch 6: val_loss improved from 24.19982 to 23.29023, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 37.7910 - mae: 4.9789 - mse: 37.7910 - val_loss: 23.2902 - val_mae: 4.5092 - val_mse: 23.2902
# Epoch 7/500
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 38.1138 - mae: 4.9727 - mse: 38.1138
# Epoch 7: val_loss improved from 23.29023 to 22.46329, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 37.8703 - mae: 4.9532 - mse: 37.8703 - val_loss: 22.4633 - val_mae: 4.4204 - val_mse: 22.4633
# Epoch 8/500
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 35.6419 - mae: 4.8806 - mse: 35.6419
# Epoch 8: val_loss improved from 22.46329 to 21.67791, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 35.6305 - mae: 4.8660 - mse: 35.6305 - val_loss: 21.6779 - val_mae: 4.3348 - val_mse: 21.6779
# Epoch 9/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 39.6613 - mae: 5.0700 - mse: 39.6613
# Epoch 9: val_loss improved from 21.67791 to 20.88345, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 38.8350 - mae: 5.0053 - mse: 38.8350 - val_loss: 20.8834 - val_mae: 4.2468 - val_mse: 20.8834
# Epoch 10/500
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 36.8180 - mae: 4.7961 - mse: 36.8180
# Epoch 10: val_loss improved from 20.88345 to 20.12365, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 36.5867 - mae: 4.7978 - mse: 36.5867 - val_loss: 20.1236 - val_mae: 4.1608 - val_mse: 20.1236
# Epoch 11/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 37.2496 - mae: 4.8823 - mse: 37.2496
# Epoch 11: val_loss improved from 20.12365 to 19.37215, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 37.7125 - mae: 4.9206 - mse: 37.7125 - val_loss: 19.3722 - val_mae: 4.0735 - val_mse: 19.3722
# Epoch 12/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 36.9634 - mae: 4.8286 - mse: 36.9634
# Epoch 12: val_loss improved from 19.37215 to 18.63478, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 36.6992 - mae: 4.8337 - mse: 36.6992 - val_loss: 18.6348 - val_mae: 3.9859 - val_mse: 18.6348
# Epoch 13/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 38.0008 - mae: 4.9382 - mse: 38.0008
# Epoch 13: val_loss improved from 18.63478 to 17.96400, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 37.8853 - mae: 4.9367 - mse: 37.8853 - val_loss: 17.9640 - val_mae: 3.9044 - val_mse: 17.9640
# Epoch 14/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 36.9697 - mae: 4.8179 - mse: 36.9697
# Epoch 14: val_loss improved from 17.96400 to 17.30890, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 36.4697 - mae: 4.7835 - mse: 36.4697 - val_loss: 17.3089 - val_mae: 3.8236 - val_mse: 17.3089
# Epoch 15/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 36.5307 - mae: 4.8154 - mse: 36.5307
# Epoch 15: val_loss improved from 17.30890 to 16.66619, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 35.4232 - mae: 4.7384 - mse: 35.4232 - val_loss: 16.6662 - val_mae: 3.7425 - val_mse: 16.6662
# Epoch 16/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 30.7221 - mae: 4.4508 - mse: 30.7221
# Epoch 16: val_loss improved from 16.66619 to 16.06846, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 30.9969 - mae: 4.4630 - mse: 30.9969 - val_loss: 16.0685 - val_mae: 3.6654 - val_mse: 16.0685
# Epoch 17/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31.4228 - mae: 4.5000 - mse: 31.4228
# Epoch 17: val_loss improved from 16.06846 to 15.50954, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 32.0977 - mae: 4.5344 - mse: 32.0977 - val_loss: 15.5095 - val_mae: 3.5929 - val_mse: 15.5095
# Epoch 18/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.4462 - mae: 4.4622 - mse: 30.4462
# Epoch 18: val_loss improved from 15.50954 to 14.97322, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 30.4797 - mae: 4.4632 - mse: 30.4797 - val_loss: 14.9732 - val_mae: 3.5227 - val_mse: 14.9732
# Epoch 19/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 35.1176 - mae: 4.7525 - mse: 35.1176
# Epoch 19: val_loss improved from 14.97322 to 14.44501, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 34.7746 - mae: 4.7228 - mse: 34.7746 - val_loss: 14.4450 - val_mae: 3.4515 - val_mse: 14.4450
# Epoch 20/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.1876 - mae: 4.5190 - mse: 32.1876
# Epoch 20: val_loss improved from 14.44501 to 13.92999, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 32.1630 - mae: 4.4966 - mse: 32.1630 - val_loss: 13.9300 - val_mae: 3.3808 - val_mse: 13.9300
# Epoch 21/500
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 32.2520 - mae: 4.4871 - mse: 32.2520
# Epoch 21: val_loss improved from 13.92999 to 13.43461, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 31.9118 - mae: 4.4714 - mse: 31.9118 - val_loss: 13.4346 - val_mae: 3.3122 - val_mse: 13.4346
# Epoch 22/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.9842 - mae: 4.5252 - mse: 32.9842
# Epoch 22: val_loss improved from 13.43461 to 12.94628, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 32.9650 - mae: 4.5236 - mse: 32.9650 - val_loss: 12.9463 - val_mae: 3.2443 - val_mse: 12.9463
# Epoch 23/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 32.5209 - mae: 4.5121 - mse: 32.5209
# Epoch 23: val_loss improved from 12.94628 to 12.45670, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 31.4525 - mae: 4.4612 - mse: 31.4525 - val_loss: 12.4567 - val_mae: 3.1758 - val_mse: 12.4567
# Epoch 24/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 30.2419 - mae: 4.3325 - mse: 30.2419
# Epoch 24: val_loss improved from 12.45670 to 12.02397, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 30.2894 - mae: 4.3455 - mse: 30.2894 - val_loss: 12.0240 - val_mae: 3.1140 - val_mse: 12.0240
# Epoch 25/500
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.2237 - mae: 4.1546 - mse: 27.2237
# Epoch 25: val_loss improved from 12.02397 to 11.61160, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 27.9115 - mae: 4.2000 - mse: 27.9115 - val_loss: 11.6116 - val_mae: 3.0540 - val_mse: 11.6116
# Epoch 26/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 30.1314 - mae: 4.3208 - mse: 30.1314
# Epoch 26: val_loss improved from 11.61160 to 11.23852, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 30.0432 - mae: 4.3145 - mse: 30.0432 - val_loss: 11.2385 - val_mae: 3.0001 - val_mse: 11.2385
# Epoch 27/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 29.4334 - mae: 4.3409 - mse: 29.4334
# Epoch 27: val_loss improved from 11.23852 to 10.87566, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - loss: 29.4254 - mae: 4.3392 - mse: 29.4254 - val_loss: 10.8757 - val_mae: 2.9466 - val_mse: 10.8757
# Epoch 28/500
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 33.0016 - mae: 4.5798 - mse: 33.0016
# Epoch 28: val_loss improved from 10.87566 to 10.52082, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 32.2924 - mae: 4.5149 - mse: 32.2924 - val_loss: 10.5208 - val_mae: 2.8937 - val_mse: 10.5208
# Epoch 29/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 31.1089 - mae: 4.4971 - mse: 31.1089
# Epoch 29: val_loss improved from 10.52082 to 10.16829, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 30.5041 - mae: 4.4566 - mse: 30.5041 - val_loss: 10.1683 - val_mae: 2.8401 - val_mse: 10.1683
# Epoch 30/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 29.9644 - mae: 4.3562 - mse: 29.9644
# Epoch 30: val_loss improved from 10.16829 to 9.82326, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 28.9839 - mae: 4.2889 - mse: 28.9839 - val_loss: 9.8233 - val_mae: 2.7869 - val_mse: 9.8233
# Epoch 31/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 28.2080 - mae: 4.1751 - mse: 28.2080
# Epoch 31: val_loss improved from 9.82326 to 9.51496, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 28.3634 - mae: 4.1828 - mse: 28.3634 - val_loss: 9.5150 - val_mae: 2.7389 - val_mse: 9.5150
# Epoch 32/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 30.6475 - mae: 4.2677 - mse: 30.6475
# Epoch 32: val_loss improved from 9.51496 to 9.20787, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 29.5560 - mae: 4.2170 - mse: 29.5560 - val_loss: 9.2079 - val_mae: 2.6904 - val_mse: 9.2079
# Epoch 33/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 28.0322 - mae: 4.2880 - mse: 28.0322
# Epoch 33: val_loss improved from 9.20787 to 8.90799, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 28.0570 - mae: 4.2632 - mse: 28.0570 - val_loss: 8.9080 - val_mae: 2.6421 - val_mse: 8.9080
# Epoch 34/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.8544 - mae: 4.1320 - mse: 26.8544
# Epoch 34: val_loss improved from 8.90799 to 8.60118, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 26.3406 - mae: 4.0962 - mse: 26.3406 - val_loss: 8.6012 - val_mae: 2.5915 - val_mse: 8.6012
# Epoch 35/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 25.6189 - mae: 4.1241 - mse: 25.6189
# Epoch 35: val_loss improved from 8.60118 to 8.32465, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 25.8792 - mae: 4.1405 - mse: 25.8792 - val_loss: 8.3247 - val_mae: 2.5451 - val_mse: 8.3247
# Epoch 36/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 26.9923 - mae: 4.2080 - mse: 26.9923
# Epoch 36: val_loss improved from 8.32465 to 8.06033, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 26.3080 - mae: 4.1377 - mse: 26.3080 - val_loss: 8.0603 - val_mae: 2.5003 - val_mse: 8.0603
# Epoch 37/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 26.2359 - mae: 4.1184 - mse: 26.2359
# Epoch 37: val_loss improved from 8.06033 to 7.79819, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 25.8704 - mae: 4.0820 - mse: 25.8704 - val_loss: 7.7982 - val_mae: 2.4577 - val_mse: 7.7982
# Epoch 38/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 27.3431 - mae: 4.1911 - mse: 27.3431
# Epoch 38: val_loss improved from 7.79819 to 7.52922, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 27.2156 - mae: 4.1601 - mse: 27.2156 - val_loss: 7.5292 - val_mae: 2.4128 - val_mse: 7.5292
# Epoch 39/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 25.9391 - mae: 4.0073 - mse: 25.9391
# Epoch 39: val_loss improved from 7.52922 to 7.28000, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 26.0800 - mae: 4.0520 - mse: 26.0800 - val_loss: 7.2800 - val_mae: 2.3711 - val_mse: 7.2800
# Epoch 40/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 26.5086 - mae: 4.0058 - mse: 26.5086
# Epoch 40: val_loss improved from 7.28000 to 7.03264, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 26.4992 - mae: 4.0442 - mse: 26.4992 - val_loss: 7.0326 - val_mae: 2.3292 - val_mse: 7.0326
# Epoch 41/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 24.3726 - mae: 3.9725 - mse: 24.3726
# Epoch 41: val_loss improved from 7.03264 to 6.79963, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 24.4150 - mae: 3.9720 - mse: 24.4150 - val_loss: 6.7996 - val_mae: 2.2890 - val_mse: 6.7996
# Epoch 42/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.4811 - mae: 4.0360 - mse: 25.4811
# Epoch 42: val_loss improved from 6.79963 to 6.58695, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 24.8724 - mae: 3.9798 - mse: 24.8724 - val_loss: 6.5869 - val_mae: 2.2518 - val_mse: 6.5869
# Epoch 43/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.0202 - mae: 4.0383 - mse: 26.0202
# Epoch 43: val_loss improved from 6.58695 to 6.38144, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 25.9743 - mae: 4.0322 - mse: 25.9743 - val_loss: 6.3814 - val_mae: 2.2153 - val_mse: 6.3814
# Epoch 44/500
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.7549 - mae: 3.8793 - mse: 23.7549
# Epoch 44: val_loss improved from 6.38144 to 6.18631, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 23.9413 - mae: 3.9006 - mse: 23.9413 - val_loss: 6.1863 - val_mae: 2.1802 - val_mse: 6.1863
# Epoch 45/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 24.4073 - mae: 3.9374 - mse: 24.4073
# Epoch 45: val_loss improved from 6.18631 to 6.00377, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 23.9673 - mae: 3.8977 - mse: 23.9673 - val_loss: 6.0038 - val_mae: 2.1464 - val_mse: 6.0038
# Epoch 46/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.2349 - mae: 3.8056 - mse: 23.2349
# Epoch 46: val_loss improved from 6.00377 to 5.82438, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 23.6846 - mae: 3.8468 - mse: 23.6846 - val_loss: 5.8244 - val_mae: 2.1132 - val_mse: 5.8244
# Epoch 47/500
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 27.1614 - mae: 4.1355 - mse: 27.1614
# Epoch 47: val_loss improved from 5.82438 to 5.63833, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 26.1081 - mae: 4.0621 - mse: 26.1081 - val_loss: 5.6383 - val_mae: 2.0788 - val_mse: 5.6383
# Epoch 48/500
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.8916 - mae: 3.9084 - mse: 23.8916
# Epoch 48: val_loss improved from 5.63833 to 5.46808, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 23.7040 - mae: 3.8767 - mse: 23.7040 - val_loss: 5.4681 - val_mae: 2.0464 - val_mse: 5.4681
# Epoch 49/500
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.4395 - mae: 3.7091 - mse: 23.4395
# Epoch 49: val_loss improved from 5.46808 to 5.32071, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 23.3121 - mae: 3.7252 - mse: 23.3121 - val_loss: 5.3207 - val_mae: 2.0179 - val_mse: 5.3207
# Epoch 50/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 25.5336 - mae: 3.9344 - mse: 25.5336
# Epoch 50: val_loss improved from 5.32071 to 5.16971, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 25.4331 - mae: 3.9278 - mse: 25.4331 - val_loss: 5.1697 - val_mae: 1.9882 - val_mse: 5.1697
# Epoch 51/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.5761 - mae: 4.1631 - mse: 25.5761
# Epoch 51: val_loss improved from 5.16971 to 5.01465, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 24.7842 - mae: 4.0451 - mse: 24.7842 - val_loss: 5.0147 - val_mae: 1.9577 - val_mse: 5.0147
# Epoch 52/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.9797 - mae: 3.8021 - mse: 22.9797
# Epoch 52: val_loss improved from 5.01465 to 4.87320, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 23.1523 - mae: 3.8245 - mse: 23.1523 - val_loss: 4.8732 - val_mae: 1.9291 - val_mse: 4.8732
# Epoch 53/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.9125 - mae: 3.6636 - mse: 20.9125
# Epoch 53: val_loss improved from 4.87320 to 4.72823, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 21.2404 - mae: 3.6776 - mse: 21.2404 - val_loss: 4.7282 - val_mae: 1.8997 - val_mse: 4.7282
# Epoch 54/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.2305 - mae: 3.7868 - mse: 22.2305
# Epoch 54: val_loss improved from 4.72823 to 4.59236, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 22.5176 - mae: 3.8031 - mse: 22.5176 - val_loss: 4.5924 - val_mae: 1.8716 - val_mse: 4.5924
# Epoch 55/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.4097 - mae: 3.5012 - mse: 19.4097
# Epoch 55: val_loss improved from 4.59236 to 4.46573, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 20.2497 - mae: 3.6010 - mse: 20.2497 - val_loss: 4.4657 - val_mae: 1.8449 - val_mse: 4.4657
# Epoch 56/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.8777 - mae: 3.6553 - mse: 21.8777
# Epoch 56: val_loss improved from 4.46573 to 4.35138, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 21.8940 - mae: 3.6613 - mse: 21.8940 - val_loss: 4.3514 - val_mae: 1.8208 - val_mse: 4.3514
# Epoch 57/500
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.4391 - mae: 3.7089 - mse: 22.4391
# Epoch 57: val_loss improved from 4.35138 to 4.23913, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 22.3335 - mae: 3.7241 - mse: 22.3335 - val_loss: 4.2391 - val_mae: 1.7972 - val_mse: 4.2391
# Epoch 58/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.9888 - mae: 3.6512 - mse: 21.9888
# Epoch 58: val_loss improved from 4.23913 to 4.13203, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 21.6136 - mae: 3.6220 - mse: 21.6136 - val_loss: 4.1320 - val_mae: 1.7745 - val_mse: 4.1320
# Epoch 59/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.8780 - mae: 3.6105 - mse: 20.8780
# Epoch 59: val_loss improved from 4.13203 to 4.02577, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 21.0623 - mae: 3.6366 - mse: 21.0623 - val_loss: 4.0258 - val_mae: 1.7513 - val_mse: 4.0258
# Epoch 60/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.6616 - mae: 3.6550 - mse: 21.6616
# Epoch 60: val_loss improved from 4.02577 to 3.91751, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 21.7735 - mae: 3.7024 - mse: 21.7735 - val_loss: 3.9175 - val_mae: 1.7274 - val_mse: 3.9175
# Epoch 61/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.3810 - mae: 3.4325 - mse: 18.3810
# Epoch 61: val_loss improved from 3.91751 to 3.82070, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 18.8930 - mae: 3.4765 - mse: 18.8930 - val_loss: 3.8207 - val_mae: 1.7059 - val_mse: 3.8207
# Epoch 62/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.6479 - mae: 3.5034 - mse: 19.6479
# Epoch 62: val_loss improved from 3.82070 to 3.72355, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 20.3776 - mae: 3.5775 - mse: 20.3776 - val_loss: 3.7236 - val_mae: 1.6838 - val_mse: 3.7236
# Epoch 63/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.5338 - mae: 3.6449 - mse: 21.5338
# Epoch 63: val_loss improved from 3.72355 to 3.62382, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 21.3460 - mae: 3.6297 - mse: 21.3460 - val_loss: 3.6238 - val_mae: 1.6606 - val_mse: 3.6238
# Epoch 64/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.8227 - mae: 3.7674 - mse: 22.8227
# Epoch 64: val_loss improved from 3.62382 to 3.52198, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 22.1951 - mae: 3.7225 - mse: 22.1951 - val_loss: 3.5220 - val_mae: 1.6367 - val_mse: 3.5220
# Epoch 65/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.4853 - mae: 3.6936 - mse: 22.4853
# Epoch 65: val_loss improved from 3.52198 to 3.42760, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 22.0406 - mae: 3.6741 - mse: 22.0406 - val_loss: 3.4276 - val_mae: 1.6142 - val_mse: 3.4276
# Epoch 66/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.2946 - mae: 3.4001 - mse: 18.2946
# Epoch 66: val_loss improved from 3.42760 to 3.34208, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 19.0902 - mae: 3.4805 - mse: 19.0902 - val_loss: 3.3421 - val_mae: 1.5936 - val_mse: 3.3421
# Epoch 67/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.5224 - mae: 3.6153 - mse: 20.5224
# Epoch 67: val_loss improved from 3.34208 to 3.26071, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 20.4412 - mae: 3.6068 - mse: 20.4412 - val_loss: 3.2607 - val_mae: 1.5736 - val_mse: 3.2607
# Epoch 68/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.9865 - mae: 3.7313 - mse: 22.9865
# Epoch 68: val_loss improved from 3.26071 to 3.17476, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 22.3529 - mae: 3.7146 - mse: 22.3529 - val_loss: 3.1748 - val_mae: 1.5520 - val_mse: 3.1748
# Epoch 69/500
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 20.5698 - mae: 3.6856 - mse: 20.5698
# Epoch 69: val_loss improved from 3.17476 to 3.08953, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 20.4787 - mae: 3.6667 - mse: 20.4787 - val_loss: 3.0895 - val_mae: 1.5298 - val_mse: 3.0895
# Epoch 70/500
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 20.4556 - mae: 3.5402 - mse: 20.4556
# Epoch 70: val_loss improved from 3.08953 to 3.00570, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 20.3909 - mae: 3.5483 - mse: 20.3909 - val_loss: 3.0057 - val_mae: 1.5079 - val_mse: 3.0057
# Epoch 71/500
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.2432 - mae: 3.4359 - mse: 19.2432
# Epoch 71: val_loss improved from 3.00570 to 2.93029, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 19.6992 - mae: 3.4843 - mse: 19.6992 - val_loss: 2.9303 - val_mae: 1.4878 - val_mse: 2.9303
# Epoch 72/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.7857 - mae: 3.6048 - mse: 20.7857
# Epoch 72: val_loss improved from 2.93029 to 2.85853, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 20.7918 - mae: 3.6065 - mse: 20.7918 - val_loss: 2.8585 - val_mae: 1.4681 - val_mse: 2.8585
# Epoch 73/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19.5702 - mae: 3.4954 - mse: 19.5702
# Epoch 73: val_loss improved from 2.85853 to 2.78697, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 19.7351 - mae: 3.5110 - mse: 19.7351 - val_loss: 2.7870 - val_mae: 1.4486 - val_mse: 2.7870
# Epoch 74/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.7539 - mae: 3.4053 - mse: 18.7539
# Epoch 74: val_loss improved from 2.78697 to 2.72620, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 18.9518 - mae: 3.4474 - mse: 18.9518 - val_loss: 2.7262 - val_mae: 1.4325 - val_mse: 2.7262
# Epoch 75/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19.4869 - mae: 3.4621 - mse: 19.4869
# Epoch 75: val_loss improved from 2.72620 to 2.66053, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 19.4277 - mae: 3.4611 - mse: 19.4277 - val_loss: 2.6605 - val_mae: 1.4147 - val_mse: 2.6605
# Epoch 76/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.8409 - mae: 3.4043 - mse: 18.8409
# Epoch 76: val_loss improved from 2.66053 to 2.59393, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 18.9310 - mae: 3.4245 - mse: 18.9310 - val_loss: 2.5939 - val_mae: 1.3961 - val_mse: 2.5939
# Epoch 77/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.9352 - mae: 3.5760 - mse: 19.9352
# Epoch 77: val_loss improved from 2.59393 to 2.52561, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 20.1727 - mae: 3.5830 - mse: 20.1727 - val_loss: 2.5256 - val_mae: 1.3765 - val_mse: 2.5256
# Epoch 78/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.3396 - mae: 3.5618 - mse: 20.3396
# Epoch 78: val_loss improved from 2.52561 to 2.46426, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 20.2274 - mae: 3.5572 - mse: 20.2274 - val_loss: 2.4643 - val_mae: 1.3587 - val_mse: 2.4643
# Epoch 79/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.6593 - mae: 3.3764 - mse: 18.6593
# Epoch 79: val_loss improved from 2.46426 to 2.40849, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 18.7478 - mae: 3.4130 - mse: 18.7478 - val_loss: 2.4085 - val_mae: 1.3425 - val_mse: 2.4085
# Epoch 80/500
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.3839 - mae: 3.6533 - mse: 20.3839
# Epoch 80: val_loss improved from 2.40849 to 2.35677, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 20.0679 - mae: 3.6095 - mse: 20.0679 - val_loss: 2.3568 - val_mae: 1.3271 - val_mse: 2.3568
# Epoch 81/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.4321 - mae: 3.4911 - mse: 19.4321
# Epoch 81: val_loss improved from 2.35677 to 2.30838, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 19.3157 - mae: 3.4833 - mse: 19.3157 - val_loss: 2.3084 - val_mae: 1.3125 - val_mse: 2.3084
# Epoch 82/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.5603 - mae: 3.5717 - mse: 20.5603
# Epoch 82: val_loss improved from 2.30838 to 2.26312, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 19.3686 - mae: 3.4631 - mse: 19.3686 - val_loss: 2.2631 - val_mae: 1.2986 - val_mse: 2.2631
# Epoch 83/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.3546 - mae: 3.4157 - mse: 18.3546
# Epoch 83: val_loss improved from 2.26312 to 2.22285, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 19.1430 - mae: 3.4929 - mse: 19.1430 - val_loss: 2.2229 - val_mae: 1.2861 - val_mse: 2.2229
# Epoch 84/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.1655 - mae: 3.2530 - mse: 17.1655
# Epoch 84: val_loss improved from 2.22285 to 2.18373, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 17.2810 - mae: 3.2659 - mse: 17.2810 - val_loss: 2.1837 - val_mae: 1.2736 - val_mse: 2.1837
# Epoch 85/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.9190 - mae: 3.1217 - mse: 15.9190
# Epoch 85: val_loss improved from 2.18373 to 2.14604, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 16.7412 - mae: 3.2141 - mse: 16.7412 - val_loss: 2.1460 - val_mae: 1.2615 - val_mse: 2.1460
# Epoch 86/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.0543 - mae: 3.5041 - mse: 20.0543
# Epoch 86: val_loss improved from 2.14604 to 2.10644, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 19.2025 - mae: 3.4449 - mse: 19.2025 - val_loss: 2.1064 - val_mae: 1.2487 - val_mse: 2.1064
# Epoch 87/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.7641 - mae: 3.1399 - mse: 15.7641
# Epoch 87: val_loss improved from 2.10644 to 2.06676, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 16.2283 - mae: 3.1946 - mse: 16.2283 - val_loss: 2.0668 - val_mae: 1.2355 - val_mse: 2.0668
# Epoch 88/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 17.8293 - mae: 3.3742 - mse: 17.8293
# Epoch 88: val_loss improved from 2.06676 to 2.02615, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 17.8546 - mae: 3.3773 - mse: 17.8546 - val_loss: 2.0262 - val_mae: 1.2218 - val_mse: 2.0262
# Epoch 89/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.6923 - mae: 3.5290 - mse: 19.6923
# Epoch 89: val_loss improved from 2.02615 to 1.98601, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 19.0271 - mae: 3.4610 - mse: 19.0271 - val_loss: 1.9860 - val_mae: 1.2079 - val_mse: 1.9860
# Epoch 90/500
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.2248 - mae: 3.4809 - mse: 19.2248
# Epoch 90: val_loss improved from 1.98601 to 1.94845, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 18.9132 - mae: 3.4582 - mse: 18.9132 - val_loss: 1.9484 - val_mae: 1.1951 - val_mse: 1.9484
# Epoch 91/500
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.6525 - mae: 3.4322 - mse: 18.6525
# Epoch 91: val_loss improved from 1.94845 to 1.91360, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 18.6507 - mae: 3.4353 - mse: 18.6507 - val_loss: 1.9136 - val_mae: 1.1827 - val_mse: 1.9136
# Epoch 92/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.0337 - mae: 3.3141 - mse: 18.0337
# Epoch 92: val_loss improved from 1.91360 to 1.87886, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 18.0085 - mae: 3.3139 - mse: 18.0085 - val_loss: 1.8789 - val_mae: 1.1706 - val_mse: 1.8789
# Epoch 93/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 17.2431 - mae: 3.3020 - mse: 17.2431
# Epoch 93: val_loss improved from 1.87886 to 1.84502, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 17.2290 - mae: 3.2995 - mse: 17.2290 - val_loss: 1.8450 - val_mae: 1.1587 - val_mse: 1.8450
# Epoch 94/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.7281 - mae: 3.4370 - mse: 18.7281
# Epoch 94: val_loss improved from 1.84502 to 1.81225, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 18.6374 - mae: 3.4288 - mse: 18.6374 - val_loss: 1.8122 - val_mae: 1.1473 - val_mse: 1.8122
# Epoch 95/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.5814 - mae: 3.2231 - mse: 16.5814
# Epoch 95: val_loss improved from 1.81225 to 1.78054, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 16.6571 - mae: 3.2319 - mse: 16.6571 - val_loss: 1.7805 - val_mae: 1.1364 - val_mse: 1.7805
# Epoch 96/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 17.2938 - mae: 3.3353 - mse: 17.2938
# Epoch 96: val_loss improved from 1.78054 to 1.74617, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 17.2358 - mae: 3.3244 - mse: 17.2358 - val_loss: 1.7462 - val_mae: 1.1240 - val_mse: 1.7462
# Epoch 97/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.3877 - mae: 3.2311 - mse: 16.3877
# Epoch 97: val_loss improved from 1.74617 to 1.71726, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 16.4408 - mae: 3.2271 - mse: 16.4408 - val_loss: 1.7173 - val_mae: 1.1133 - val_mse: 1.7173
# Epoch 98/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.9096 - mae: 3.1811 - mse: 15.9096
# Epoch 98: val_loss improved from 1.71726 to 1.68866, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 16.1555 - mae: 3.1863 - mse: 16.1555 - val_loss: 1.6887 - val_mae: 1.1026 - val_mse: 1.6887
# Epoch 99/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.1232 - mae: 3.2864 - mse: 17.1232
# Epoch 99: val_loss improved from 1.68866 to 1.66288, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 16.9262 - mae: 3.2758 - mse: 16.9262 - val_loss: 1.6629 - val_mae: 1.0928 - val_mse: 1.6629
# Epoch 100/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.5732 - mae: 3.2159 - mse: 16.5732
# Epoch 100: val_loss improved from 1.66288 to 1.63543, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 16.5310 - mae: 3.2103 - mse: 16.5310 - val_loss: 1.6354 - val_mae: 1.0826 - val_mse: 1.6354
# Epoch 101/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.6125 - mae: 3.1771 - mse: 16.6125
# Epoch 101: val_loss improved from 1.63543 to 1.61318, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 16.6039 - mae: 3.1807 - mse: 16.6039 - val_loss: 1.6132 - val_mae: 1.0743 - val_mse: 1.6132
# Epoch 102/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.1085 - mae: 3.4860 - mse: 19.1085
# Epoch 102: val_loss improved from 1.61318 to 1.59068, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 18.4259 - mae: 3.4259 - mse: 18.4259 - val_loss: 1.5907 - val_mae: 1.0657 - val_mse: 1.5907
# Epoch 103/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.2825 - mae: 3.1881 - mse: 16.2825
# Epoch 103: val_loss improved from 1.59068 to 1.56620, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 16.2588 - mae: 3.1862 - mse: 16.2588 - val_loss: 1.5662 - val_mae: 1.0562 - val_mse: 1.5662
# Epoch 104/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.3256 - mae: 3.3602 - mse: 18.3256
# Epoch 104: val_loss improved from 1.56620 to 1.54318, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 18.1041 - mae: 3.3487 - mse: 18.1041 - val_loss: 1.5432 - val_mae: 1.0473 - val_mse: 1.5432
# Epoch 105/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.7545 - mae: 3.2418 - mse: 16.7545
# Epoch 105: val_loss improved from 1.54318 to 1.51932, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 16.7258 - mae: 3.2460 - mse: 16.7258 - val_loss: 1.5193 - val_mae: 1.0378 - val_mse: 1.5193
# Epoch 106/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.9151 - mae: 3.1048 - mse: 15.9151
# Epoch 106: val_loss improved from 1.51932 to 1.49660, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 15.8942 - mae: 3.1022 - mse: 15.8942 - val_loss: 1.4966 - val_mae: 1.0289 - val_mse: 1.4966
# Epoch 107/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.4466 - mae: 3.3546 - mse: 17.4466
# Epoch 107: val_loss improved from 1.49660 to 1.47499, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 17.3921 - mae: 3.3488 - mse: 17.3921 - val_loss: 1.4750 - val_mae: 1.0203 - val_mse: 1.4750
# Epoch 108/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.9715 - mae: 3.1936 - mse: 15.9715
# Epoch 108: val_loss improved from 1.47499 to 1.45559, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 15.9837 - mae: 3.1953 - mse: 15.9837 - val_loss: 1.4556 - val_mae: 1.0128 - val_mse: 1.4556
# Epoch 109/500
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 16.9046 - mae: 3.2759 - mse: 16.9046
# Epoch 109: val_loss improved from 1.45559 to 1.43454, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 16.7644 - mae: 3.2715 - mse: 16.7644 - val_loss: 1.4345 - val_mae: 1.0046 - val_mse: 1.4345
# Epoch 110/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 15.5522 - mae: 3.0936 - mse: 15.5522
# Epoch 110: val_loss improved from 1.43454 to 1.41672, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - loss: 15.5480 - mae: 3.0950 - mse: 15.5480 - val_loss: 1.4167 - val_mae: 0.9976 - val_mse: 1.4167
# Epoch 111/500
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 14.5178 - mae: 3.0428 - mse: 14.5178
# Epoch 111: val_loss improved from 1.41672 to 1.39864, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 14.7535 - mae: 3.0667 - mse: 14.7535 - val_loss: 1.3986 - val_mae: 0.9906 - val_mse: 1.3986
# Epoch 112/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 15.7913 - mae: 3.0697 - mse: 15.7913
# Epoch 112: val_loss improved from 1.39864 to 1.38181, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 15.7859 - mae: 3.0716 - mse: 15.7859 - val_loss: 1.3818 - val_mae: 0.9841 - val_mse: 1.3818
# Epoch 113/500
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 14.2006 - mae: 2.9442 - mse: 14.2006
# Epoch 113: val_loss improved from 1.38181 to 1.36453, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 14.3042 - mae: 2.9643 - mse: 14.3042 - val_loss: 1.3645 - val_mae: 0.9772 - val_mse: 1.3645
# Epoch 114/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 15.6650 - mae: 3.1278 - mse: 15.6650
# Epoch 114: val_loss improved from 1.36453 to 1.34668, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 15.6721 - mae: 3.1284 - mse: 15.6721 - val_loss: 1.3467 - val_mae: 0.9696 - val_mse: 1.3467
# Epoch 115/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 15.2985 - mae: 3.0871 - mse: 15.2985
# Epoch 115: val_loss improved from 1.34668 to 1.33173, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 15.3397 - mae: 3.0900 - mse: 15.3397 - val_loss: 1.3317 - val_mae: 0.9633 - val_mse: 1.3317
# Epoch 116/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 16.3122 - mae: 3.2126 - mse: 16.3122
# Epoch 116: val_loss improved from 1.33173 to 1.31491, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 16.2656 - mae: 3.2079 - mse: 16.2656 - val_loss: 1.3149 - val_mae: 0.9565 - val_mse: 1.3149
# Epoch 117/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 15.9933 - mae: 3.2405 - mse: 15.9933
# Epoch 117: val_loss improved from 1.31491 to 1.29746, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 16.0593 - mae: 3.2419 - mse: 16.0593 - val_loss: 1.2975 - val_mae: 0.9495 - val_mse: 1.2975
# Epoch 118/500
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 14.5928 - mae: 3.0631 - mse: 14.5928
# Epoch 118: val_loss improved from 1.29746 to 1.28193, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 14.8041 - mae: 3.0736 - mse: 14.8041 - val_loss: 1.2819 - val_mae: 0.9433 - val_mse: 1.2819
# Epoch 119/500
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 15.2147 - mae: 3.0881 - mse: 15.2147
# Epoch 119: val_loss improved from 1.28193 to 1.26991, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 15.3671 - mae: 3.1080 - mse: 15.3671 - val_loss: 1.2699 - val_mae: 0.9382 - val_mse: 1.2699
# Epoch 120/500
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 15.2020 - mae: 3.0680 - mse: 15.2020
# Epoch 120: val_loss improved from 1.26991 to 1.25817, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 15.0547 - mae: 3.0554 - mse: 15.0547 - val_loss: 1.2582 - val_mae: 0.9333 - val_mse: 1.2582
# Epoch 121/500
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.7729 - mae: 3.0652 - mse: 14.7729
# Epoch 121: val_loss improved from 1.25817 to 1.24800, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 14.9827 - mae: 3.0843 - mse: 14.9827 - val_loss: 1.2480 - val_mae: 0.9290 - val_mse: 1.2480
# Epoch 122/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.8377 - mae: 3.1893 - mse: 15.8377
# Epoch 122: val_loss improved from 1.24800 to 1.23508, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 15.7882 - mae: 3.1849 - mse: 15.7882 - val_loss: 1.2351 - val_mae: 0.9238 - val_mse: 1.2351
# Epoch 123/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.0704 - mae: 2.9566 - mse: 14.0704
# Epoch 123: val_loss improved from 1.23508 to 1.22284, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 14.2297 - mae: 2.9733 - mse: 14.2297 - val_loss: 1.2228 - val_mae: 0.9191 - val_mse: 1.2228
# Epoch 124/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.3864 - mae: 3.2355 - mse: 16.3864
# Epoch 124: val_loss improved from 1.22284 to 1.20959, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 16.3729 - mae: 3.2331 - mse: 16.3729 - val_loss: 1.2096 - val_mae: 0.9139 - val_mse: 1.2096
# Epoch 125/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.1044 - mae: 3.2203 - mse: 16.1044
# Epoch 125: val_loss improved from 1.20959 to 1.19658, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 16.0722 - mae: 3.2133 - mse: 16.0722 - val_loss: 1.1966 - val_mae: 0.9085 - val_mse: 1.1966
# Epoch 126/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 14.9301 - mae: 3.0942 - mse: 14.9301
# Epoch 126: val_loss improved from 1.19658 to 1.18589, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 14.9446 - mae: 3.0945 - mse: 14.9446 - val_loss: 1.1859 - val_mae: 0.9043 - val_mse: 1.1859
# Epoch 127/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.4870 - mae: 2.9835 - mse: 14.4870
# Epoch 127: val_loss improved from 1.18589 to 1.17460, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 14.3086 - mae: 2.9749 - mse: 14.3086 - val_loss: 1.1746 - val_mae: 0.8996 - val_mse: 1.1746
# Epoch 128/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.5601 - mae: 3.0280 - mse: 14.5601
# Epoch 128: val_loss improved from 1.17460 to 1.16491, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 14.4609 - mae: 3.0249 - mse: 14.4609 - val_loss: 1.1649 - val_mae: 0.8957 - val_mse: 1.1649
# Epoch 129/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.8620 - mae: 3.0629 - mse: 14.8620
# Epoch 129: val_loss improved from 1.16491 to 1.15381, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 14.8910 - mae: 3.0613 - mse: 14.8910 - val_loss: 1.1538 - val_mae: 0.8911 - val_mse: 1.1538
# Epoch 130/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.2499 - mae: 3.0986 - mse: 15.2499
# Epoch 130: val_loss improved from 1.15381 to 1.14141, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 15.2405 - mae: 3.0985 - mse: 15.2405 - val_loss: 1.1414 - val_mae: 0.8856 - val_mse: 1.1414
# Epoch 131/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.3782 - mae: 3.1338 - mse: 15.3782
# Epoch 131: val_loss improved from 1.14141 to 1.12975, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 15.3527 - mae: 3.1330 - mse: 15.3527 - val_loss: 1.1298 - val_mae: 0.8805 - val_mse: 1.1298
# Epoch 132/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.8640 - mae: 3.2728 - mse: 16.8640
# Epoch 132: val_loss improved from 1.12975 to 1.11702, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 16.7926 - mae: 3.2666 - mse: 16.7926 - val_loss: 1.1170 - val_mae: 0.8749 - val_mse: 1.1170
# Epoch 133/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.9441 - mae: 2.9915 - mse: 13.9441
# Epoch 133: val_loss improved from 1.11702 to 1.10549, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 13.9570 - mae: 2.9856 - mse: 13.9570 - val_loss: 1.1055 - val_mae: 0.8697 - val_mse: 1.1055
# Epoch 134/500
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.0796 - mae: 3.1137 - mse: 16.0796
# Epoch 134: val_loss improved from 1.10549 to 1.09594, saving model to tsmixer_checkpoints/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 15.2671 - mae: 3.0515 - mse: 15.2671 - val_loss: 1.0959 - val_mae: 0.8653 - val_mse: 1.0959
# Epoch 135/500

# %%
print(f"Лучшая эпоха: {np.argmin(history.history['val_loss'])}")

# %%
model.load_weights("tsmixer_checkpoints/model.weights.h5")

# %%
predictions = model.predict(tf_test_data)

scaled_preds = predictions[-1,:,:]

preds = data_loader.inverse_transform(scaled_preds)
preds_df = pd.DataFrame(preds)
preds_df

# %%
class TSMixer(Strategy):
    def init(self) -> None:
        self.data_loader = data_loader
        self.model = model

        self.forecasts = self.I(lambda: np.repeat(np.nan, len(self.data)), name='forecast')

    def next(self) -> None:
        if len(self.data) <= TSMIXER_CFG.WINDOW+1:
            return

        scaled_prices = self.data_loader._make_dataset(
            self.data_loader.scaler.transform(self.data.df[["Close"]][-(TSMIXER_CFG.WINDOW+1):]),
            shuffle=False
            )

        predicted_close_price = self.data_loader.inverse_transform(
            self.model.predict(scaled_prices, verbose=0)[-1,:,:]
            )[0][0]

        self.forecasts[-1] = predicted_close_price

        if self.data.Close / predicted_close_price < 0.99:
            self.position.close()
            self.buy()

        elif self.data.Close / predicted_close_price > 1.01:
            self.position.close()
            self.sell()

# %%
run_backtest(tf_test_data, TSMixer)

# %%
class TSMixerEnsemble(Strategy):
    n1 = 5
    n2 = 10

    def init(self) -> None:
        self.data_loader = data_loader
        self.model = model
        self.sma1 = self.I(SMA, self.data.Close, self.n1)
        self.sma2 = self.I(SMA, self.data.Close, self.n2)

        self.forecasts = self.I(lambda: np.repeat(np.nan, len(self.data)), name='forecast')

    def next(self) -> None:
        if len(self.data) <= TSMIXER_CFG.WINDOW+1:
            return

        scaled_prices = self.data_loader._make_dataset(
            self.data_loader.scaler.transform(self.data.df[["Close"]][-(TSMIXER_CFG.WINDOW+1):]),
            shuffle=False
            )

        predicted_close_price = self.data_loader.inverse_transform(
            self.model.predict(scaled_prices, verbose=0)[-1,:,:]
            )[0][0]

        self.forecasts[-1] = predicted_close_price

        if crossover(self.sma1, self.sma2) and (self.data.Close / predicted_close_price < 0.99):
            self.position.close()
            self.buy()

        elif crossover(self.sma2, self.sma1) and (self.data.Close / predicted_close_price > 1.01):
            self.position.close()
            self.sell()

# %%
run_backtest(tf_test_data, TSMixerEnsemble)
